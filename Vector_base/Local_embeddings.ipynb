# %%
import os
from langchain_community.embeddings import OllamaEmbeddings
from langchain_community.vectorstores.chroma import Chroma
from langchain_experimental.text_splitter import SemanticChunker
from langchain.schema import Document  # Import the Document class
import pdfplumber
from werkzeug.utils import secure_filename
from datetime import datetime

# %%
CHROMA_PATH = os.getenv('CHROMA_PATH', 'chroma_embeddings')
COLLECTION_NAME = os.getenv('COLLECTION_NAME', 'local-rag')
TEXT_EMBEDDING_MODEL = os.getenv('TEXT_EMBEDDING_MODEL', 'nomic-embed-text')  # Default model
TEMP_FOLDER = os.getenv('TEMP_FOLDER', './_temp')

# %%
embedding = OllamaEmbeddings(model=TEXT_EMBEDDING_MODEL, show_progress=True)
# Out:
# C:\Users\somaa\AppData\Local\Temp\ipykernel_19576\3451156522.py:1: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaEmbeddings``.
#   embedding = OllamaEmbeddings(model=TEXT_EMBEDDING_MODEL, show_progress=True)

# %%
def get_vector_db():
    # Initialize and return the vector DB
    db = Chroma(
        collection_name=COLLECTION_NAME,
        persist_directory=CHROMA_PATH,
        embedding_function=embedding
    )
    return db

# %%
def allowed_file(filename):
    return '.' in filename and filename.rsplit('.', 1)[1].lower() in {'pdf'}

# %%
def save_file(file):
    ct = datetime.now()
    ts = ct.timestamp()
    filename = str(ts) + "_" + secure_filename(file.filename)
    file_path = os.path.join(TEMP_FOLDER, filename)
    file.save(file_path)

    return file_path

# %%
def load_and_split_data(file_path):
    # Load the PDF using pdfplumber
    with pdfplumber.open(file_path) as pdf:
        text = ""
        # Extract text from each page
        for page in pdf.pages:
            text += page.extract_text()

    # Create Document objects from the extracted text
    documents = [Document(page_content=text)]  # Wrap the text as a Document

    # Initialize the SemanticChunker for semantic-based chunking
    chunker = SemanticChunker(embeddings=embedding)

    # Split the text into semantic chunks
    chunks = chunker.split_documents(documents)  # Pass the list of Document objects

    return chunks

# %%
def embed_multiple_pdfs(file_paths):
    db = get_vector_db()

    for file_path in file_paths:
        if os.path.exists(file_path) and allowed_file(file_path):
            # Load and split data from the PDF file
            chunks = load_and_split_data(file_path)
            # Add documents to the database
            db.add_documents(chunks)
        else:
            print(f"File '{file_path}' is either invalid or does not exist.")

    # Persist the changes in the database
    db.persist()
    print(f"All documents have been processed and stored in ChromaDB.")

# %%
pdf_paths = [r"C:\Users\somaa\Desktop\RAG_INternship\goog-10-k-2023 (1).pdf",
             r"C:\Users\somaa\Desktop\RAG_INternship\tsla-20231231-gen.pdf",
             r"C:\Users\somaa\Desktop\RAG_INternship\uber-10-k-2023.pdf"  ]

# %%
embed_multiple_pdfs(pdf_paths)
# Out:
# C:\Users\somaa\AppData\Local\Temp\ipykernel_19576\3260405828.py:3: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   db = Chroma(
#
#
#
#
#
#
# llamaEmbeddings: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 169/169 [10:11<00:00,  3.62s/it]
# All documents have been processed and stored in ChromaDB.
# C:\Users\somaa\AppData\Local\Temp\ipykernel_19576\1775851335.py:14: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   db.persist()

# %%
def inspect_stored_embeddings():
    db = get_vector_db()
    
    # Fetch stored embeddings, documents, and metadata
    collection_data = db._collection.get(include=['embeddings', 'documents'])
    embeddings = collection_data['embeddings']
    documents = collection_data['documents']
    
    
    for idx, (embedding, document) in enumerate(zip(embeddings, documents)):
        print(f"Document {idx + 1}:")
        print(f"Content: {document[:200]}...")  # Show first 200 characters of the document
        print(f"Embedding (first 5 dimensions): {embedding[:5]}...\n")  # Show first 5 dimensions of the embedding for brevity

# Call this function to inspect the embeddings and associated data
inspect_stored_embeddings()
# Out:
# Document 1:
# Content: UNITED STATES
# SECURITIES AND EXCHANGE COMMISSION
# Washington, D.C. 20549
# ___________________________________________
# FORM 10-K
# ___________________________________________
# (Mark One)
# ☒ ANNUAL REPORT PUR...
# Embedding (first 5 dimensions): [ 0.21078122  0.5575794  -2.25715327 -0.26436976  0.51947939]...
#
# Document 2:
# Content: Yes ☐ No ☒
# Indicate by check mark whether the registrant (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities
# Exchange Act of 1934 during the preceding 12 months (or...
# Embedding (first 5 dimensions): [ 0.3889789   0.89617568 -3.19549012  0.04632065  0.74298537]...
#
# Document 3:
# Content: ☒
# If securities are registered pursuant to Section 12(b) of the Act, indicate by check mark whether the financial statements of the
# registrant included in the filing reflect the correction of an error...
# Embedding (first 5 dimensions): [-0.02432753  1.30236888 -2.90390491 -1.33956206 -0.26673007]...
#
# Document 4:
# Content: Risk Factors 11
# Item 1B. Unresolved Staff Comments 24
# Item 1C. Cybersecurity 24
# Item 2....
# Embedding (first 5 dimensions): [ 1.09100425  0.76643205 -3.26639128 -0.76537281  1.87167311]...
#
# Document 5:
# Content: Properties 25
# Item 3....
# Embedding (first 5 dimensions): [ 0.05469548  0.09719427 -3.60037589 -2.03557515 -0.1139202 ]...
#
# Document 6:
# Content: Legal Proceedings 25
# Item 4. Mine Safety Disclosures 25
# PART II
# Item 5. Market for Registrant’s Common Equity, Related Stockholder Matters, and Issuer Purchases 25
# of Equity Securities
# Item 6. [Reserv...
# Embedding (first 5 dimensions): [ 0.75759286  0.36028898 -3.01389074 -0.42128408  0.9795171 ]...
#
# Document 7:
# Content: Other Information 89
# Item 9C. Disclosure Regarding Foreign Jurisdictions that Prevent Inspections 89
# PART III
# Item 10. Directors, Executive Officers, and Corporate Governance 90
# Item 11. Executive Com...
# Embedding (first 5 dimensions): [ 0.4108358   1.24685478 -2.67339253 -0.59339374  0.10552941]...
#
# Document 8:
# Content: Note About Forward-Looking Statements
# This Annual Report on Form 10-K contains forward-looking statements within the meaning of the Private
# Securities Litigation Reform Act of 1995. These include, amo...
# Embedding (first 5 dimensions): [ 0.28739548  1.84754467 -2.88224101 -0.5199371   0.04601503]...
#
# Document 9:
# Content: Forward-looking statements may appear throughout this report and other documents we file with the Securities and
# Exchange Commission (SEC), including without limitation, the following sections: Part I...
# Embedding (first 5 dimensions): [ 0.49138695  0.80333859 -3.16100883 -0.45916015  0.76393831]...
#
# Document 10:
# Content: Given these risks and uncertainties, readers are cautioned not to place undue reliance on such
# forward-looking statements. As used herein, "Alphabet," "the company," "we," "us," "our," and similar ter...
# Embedding (first 5 dimensions): [ 0.04770962  1.47872055 -2.83659673 -0.23750712  0.71328944]...
#
# Document 11:
# Content: This drive to make information more accessible and helpful has led us over the years to improve the discovery
# and creation of digital content both on the web and through platforms like Google Play and...
# Embedding (first 5 dimensions): [-0.59746689  2.03690791 -2.58069515 -0.29246861  1.06740844]...
#
# Document 12:
# Content: For additional information about competition, see Item 1A Risk Factors of this Annual Report on Form 10-K. Ongoing Commitment to Sustainability
# We believe that every business has the opportunity and o...
# Embedding (first 5 dimensions): [ 0.64588481  1.75518298 -2.75739169 -0.71166271  0.82257879]...
#
# Document 13:
# Content: ITEM 1A. RISK FACTORS
# Our operations and financial results are subject to various risks and uncertainties, including but not limited to
# those described below, which could harm our business, reputation...
# Embedding (first 5 dimensions): [ 0.72937459  1.73439908 -2.85252023 -0.12049806  0.85735059]...
#
# Document 14:
# Content: International revenues accounted for approximately 53% of our consolidated revenues in 2023. In
# addition to risks described elsewhere in this section, our international operations expose us to other r...
# Embedding (first 5 dimensions): [ 0.35171995  2.03133106 -3.05735159 -0.00609895  0.90232551]...
#
# Document 15:
# Content: dollars but report our financial results in U.S. dollars,
# we have faced, and will continue to face, exposure to fluctuations in foreign currency exchange rates. Although we
# hedge a portion of our inte...
# Embedding (first 5 dimensions): [ 0.68330324  1.68241715 -2.26665568  0.09263681  1.29238808]...
#
# Document 16:
# Content: There is also no guarantee that a series of related issues may not be determined to be material at a
# later date in the aggregate, even if they may not be material individually at the time of their occ...
# Embedding (first 5 dimensions): [ 2.07280391e-03  2.38538980e+00 -2.27941346e+00 -9.44557041e-03
#   1.20849371e+00]...
#
# Document 17:
# Content: government, among other things, to regulate
# private sector use and development of certain foundation models. • Data privacy, collection, and processing: Laws and regulations further restricting the co...
# Embedding (first 5 dimensions): [ 0.98860252  2.11705542 -2.52958536  0.02087095  1.08009303]...
#
# Document 18:
# Content: We plan to appeal....
# Embedding (first 5 dimensions): [ 1.26777828  1.75462615 -3.31258106 -0.8707087   0.90789628]...
#
# Document 19:
# Content: In addition, the U.S....
# Embedding (first 5 dimensions): [ 0.50499344  1.41449964 -3.47093868 -0.15327521  0.55433404]...
#
# Document 20:
# Content: Department of Justice,
# various U.S. states, and other plaintiffs have filed several antitrust lawsuits about various aspects of our business,
# including our advertising technologies and practices, the ...
# Embedding (first 5 dimensions): [ 0.80925816  1.9477272  -2.5555985   0.09184372  0.92992359]...
#
# Document 21:
# Content: or international tax legislation, or
# exposure to additional tax liabilities. We are subject to a variety of taxes and tax collection obligations in the U.S. and numerous foreign jurisdictions. Our eff...
# Embedding (first 5 dimensions): [-0.60228628  0.63343209 -3.01563191  0.23075444  0.6078527 ]...
#
# Document 22:
# Content: UNRESOLVED STAFF COMMENTS
# Not applicable....
# Embedding (first 5 dimensions): [ 1.43565071  0.78134644 -2.96857262 -1.38091171  1.21204591]...
#
# Document 23:
# Content: ITEM 1C. CYBERSECURITY
# We maintain a comprehensive process for identifying, assessing, and managing material risks from cybersecurity
# threats as part of our broader risk management system and processe...
# Embedding (first 5 dimensions): [ 0.92654693  0.59420198 -2.33944607 -0.01137137  0.93631965]...
#
# Document 24:
# Content: ITEM 2....
# Embedding (first 5 dimensions): [ 0.1063033  -0.01644583 -3.6497097  -0.76903635  0.30663013]...
#
# Document 25:
# Content: PROPERTIES
# Our headquarters are located in Mountain View, California. We own and lease office facilities and data centers
# around the world, primarily in Asia, Europe, and North America. We believe our...
# Embedding (first 5 dimensions): [ 0.48039332  1.76062846 -3.94906378 -0.08722064  0.57452214]...
#
# Document 26:
# Content: ITEM 3. LEGAL PROCEEDINGS
# For a description of our material pending legal proceedings, see Legal Matters in Note 10 of the Notes to
# Consolidated Financial Statements included in Part II, Item 8 of thi...
# Embedding (first 5 dimensions): [ 1.10181677  0.47918573 -2.47609353 -0.5706532   0.10226044]...
#
# Document 27:
# Content: MINE SAFETY DISCLOSURES
# Not applicable. PART II
# ITEM 5. MARKET FOR REGISTRANT’S COMMON EQUITY, RELATED STOCKHOLDER MATTERS, AND
# ISSUER PURCHASES OF EQUITY SECURITIES
# As of October 2, 2015, Alphabet In...
# Embedding (first 5 dimensions): [-0.26097295  1.45880198 -3.4972477  -0.74781269  1.25161219]...
#
# Document 28:
# Content: We regularly evaluate our cash and capital structure,
# including the size, pace, and form of capital return to stockholders. 25.Table of Contents Alphabet Inc. Issuer Purchases of Equity Securities
# The...
# Embedding (first 5 dimensions): [-0.90341556  1.46136498 -4.16738701 -1.16175568  1.12650526]...
#
# Document 29:
# Content: All rights reserved. 27.Table of Contents Alphabet Inc. The graph below matches Alphabet Inc. Class C's cumulative five-year total stockholder return on capital stock
# with the cumulative total returns...
# Embedding (first 5 dimensions): [ 0.08138971  1.89410949 -3.28870296 -0.98919702  0.57316518]...
#
# Document 30:
# Content: All rights reserved....
# Embedding (first 5 dimensions): [ 1.37438989  0.78461146 -3.33865356  0.04239744  0.51988614]...
#
# Document 31:
# Content: ITEM 6. [Reserved]
# 28.Table of Contents Alphabet Inc....
# Embedding (first 5 dimensions): [-0.34650725  0.96584547 -2.81989264 -1.8053689   0.02905286]...
#
# Document 32:
# Content: ITEM 7. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF
# OPERATIONS
# Please read the following discussion and analysis of our financial condition and results of operations tog...
# Embedding (first 5 dimensions): [ 0.39817527  1.9420259  -1.92539752  0.40511495  0.44916919]...
#
# Document 33:
# Content: For additional information, see Item 1A Risk
# Factors and Legal Matters in Note 10 of the Notes to Consolidated Financial Statements included in Part II, Item 8 of
# this Annual Report on Form 10-K. • Ou...
# Embedding (first 5 dimensions): [-0.34839311  2.02132821 -2.67082763 -0.53787416  0.4845188 ]...
#
# Document 34:
# Content: The provision includes the effect of reserve provisions and
# changes to reserves that are considered appropriate as well as the related net interest and penalties. For additional information, including...
# Embedding (first 5 dimensions): [ 0.67309892  0.85664845 -2.24390435 -0.22691034  0.07812031]...
#
# Document 35:
# Content: 34.Table of Contents Alphabet Inc. • On July 21, 2023, the IRS announced a rule change allowing taxpayers to temporarily apply the regulations in
# effect prior to 2022 related to U.S. federal foreign t...
# Embedding (first 5 dimensions): [-0.03581271  2.25053167 -2.46350479 -0.83842784  0.05232408]...
#
# Document 36:
# Content: For additional information relating to our segments, see Note 15 of the Notes to
# Consolidated Financial Statements included in Item 8 of this Annual Report on Form 10-K. Google Services
# Google Service...
# Embedding (first 5 dimensions): [ 1.12435877  0.45258272 -1.72715795 -0.59040046 -0.16711915]...
#
# Document 37:
# Content: We primarily utilize contract manufacturers for the assembly of our servers used in our technical infrastructure
# and devices we sell. We have agreements where we may purchase components directly from ...
# Embedding (first 5 dimensions): [-0.01600512  1.64687717 -3.3236568  -0.67983645  0.48312101]...
#
# Document 38:
# Content: 42.Table of Contents Alphabet Inc. European Commission Fines
# In 2017, 2018 and 2019, the EC announced decisions that certain actions taken by Google infringed European
# competition law and imposed fine...
# Embedding (first 5 dimensions): [ 0.95279151  0.89210576 -2.87852216  0.55825478 -0.05958936]...
#
# Document 39:
# Content: The amounts to be paid under these agreements are based on the actual volumes to be generated and
# are not readily determinable. Critical Accounting Estimates
# We prepare our consolidated financial stat...
# Embedding (first 5 dimensions): [ 0.61278552  0.36271128 -2.64043188 -1.06137717  0.10772925]...
#
# Document 40:
# Content: ITEM 7A. QUANTITATIVE AND QUALITATIVE DISCLOSURES ABOUT MARKET RISK
# We are exposed to financial market risks, including changes in foreign currency exchange rates, interest rates,
# and equity investmen...
# Embedding (first 5 dimensions): [ 0.05960342  0.73890901 -3.41735387 -0.70087099 -0.5090946 ]...
#
# Document 41:
# Content: Alphabet Inc....
# Embedding (first 5 dimensions): [-0.40858203  2.04354024 -3.92358208 -1.06520867  0.11908104]...
#
# Document 42:
# Content: CONSOLIDATED BALANCE SHEETS
# (in millions, except par value per share amounts)
# As of December 31,
# 2022 2023
# Assets
# Current assets:
# Cash and cash equivalents $ 21,879 $ 24,048
# Marketable securities 91,8...
# Embedding (first 5 dimensions): [ 0.0619688   1.1814791  -3.30034757 -1.14772558  0.07781629]...
#
# Document 43:
# Content: Alphabet Inc. CONSOLIDATED STATEMENTS OF INCOME
# (in millions, except per share amounts)
# Year Ended December 31,
# 2021 2022 2023
# Revenues $ 257,637 $ 282,836 $ 307,394
# Costs and expenses:
# Cost of revenu...
# Embedding (first 5 dimensions): [ 0.50891864  0.55951661 -2.8246491  -0.76485109 -0.47765392]...
#
# Document 44:
# Content: Alphabet Inc....
# Embedding (first 5 dimensions): [-0.40858203  2.04354024 -3.92358208 -1.06520867  0.11908104]...
#
# Document 45:
# Content: CONSOLIDATED STATEMENTS OF STOCKHOLDERS’ EQUITY
# (in millions)
# Class A, Class B, Class C
# Accumulated
# Stock and
# Other Total
# Additional Paid-In Capital
# Comprehensive Retained Stockholders’
# Shares Amount ...
# Embedding (first 5 dimensions): [ 0.63726854  0.45443806 -4.16035604  0.02168969  1.00568843]...
#
# Document 46:
# Content: Alphabet Inc. CONSOLIDATED STATEMENTS OF CASH FLOWS
# (in millions)
# Year Ended December 31,
# 2021 2022 2023
# Operating activities
# Net income $ 76,033 $ 59,972 $ 73,795
# Adjustments:
# Depreciation of propert...
# Embedding (first 5 dimensions): [ 1.19994354  1.1375829  -2.63241553 -0.68604779  0.59271407]...
#
# Document 47:
# Content: Alphabet Inc....
# Embedding (first 5 dimensions): [-0.40858203  2.04354024 -3.92358208 -1.06520867  0.11908104]...
#
# Document 48:
# Content: NOTES TO CONSOLIDATED FINANCIAL STATEMENTS
# Note 1. Summary of Significant Accounting Policies
# Nature of Operations
# Google was incorporated in California in September 1998 and re-incorporated in the St...
# Embedding (first 5 dimensions): [-0.20674244  1.9385457  -3.44003963 -1.03811991  0.92850292]...
#
# Document 49:
# Content: Sales and other
# similar taxes are excluded from revenues. Advertising Revenues
# We generate advertising revenues primarily by delivering advertising on:
# • Google Search and other properties, including ...
# Embedding (first 5 dimensions): [ 0.68431854  1.0841012  -2.51788497 -0.63108104  0.54295063]...
#
# Document 50:
# Content: Note 2. Revenues
# Disaggregated Revenues
# The following table presents revenues disaggregated by type (in millions):
# Year Ended December 31,
# 2021 2022 2023
# Google Search & other $ 148,951 $ 162,450 $ 17...
# Embedding (first 5 dimensions): [ 1.2240417   1.09214175 -2.78307509 -0.90302175  0.476349  ]...
#
# Document 51:
# Content: 65.Table of Contents Alphabet Inc....
# Embedding (first 5 dimensions): [-0.09683792  1.32526457 -3.12035203 -2.06366062 -0.16224259]...
#
# Document 52:
# Content: Debt Securities
# The following table summarizes the estimated fair value of investments in available-for-sale marketable debt
# securities by effective contractual maturity dates (in millions):
# As of Dec...
# Embedding (first 5 dimensions): [ 1.55117023  1.27799225 -2.87635207 -1.5654099   0.67482984]...
#
# Document 53:
# Content: Gains and losses, including impairments, are included as a component of OI&E in the Consolidated Statements of
# Income. See Note 7 for further details on OI&E. The carrying values for marketable and no...
# Embedding (first 5 dimensions): [ 0.50876534  1.30164456 -3.4671793  -1.30060112  0.35582381]...
#
# Document 54:
# Content: Gains and Losses on Marketable and Non-marketable Equity Securities
# Gains and losses (including impairments), net, for marketable and non-marketable equity securities included in
# OI&E are summarized b...
# Embedding (first 5 dimensions): [ 0.25480378  1.47962534 -3.35031462 -0.87575126  0.31994754]...
#
# Document 55:
# Content: In the table above, realized net gain (loss) on equity securities sold during the period reflects the difference
# between the sale proceeds and the carrying value of the equity securities at the beginn...
# Embedding (first 5 dimensions): [ 0.69164389  1.2226187  -3.15777802 -0.66897064  0.43709105]...
#
# Document 56:
# Content: See Note 7 for further details on OI&E....
# Embedding (first 5 dimensions): [ 0.21000047  1.55661559 -3.37666631 -0.49373555  0.56701267]...
#
# Document 57:
# Content: 67.Table of Contents Alphabet Inc. Derivative Financial Instruments
# We use derivative instruments to manage risks relating to our ongoing business operations. The primary risk
# managed is foreign excha...
# Embedding (first 5 dimensions): [ 1.17388391  0.88116306 -2.79212332 -0.88320798  0.85503638]...
#
# Document 58:
# Content: 68.Table of Contents Alphabet Inc. The gross notional amounts of outstanding derivative instruments were as follows (in millions):
# As of December 31,
# 2022 2023
# Derivatives designated as hedging instru...
# Embedding (first 5 dimensions): [ 1.13580716  1.00803435 -2.20436525 -0.93426228  0.94134313]...
#
# Document 59:
# Content: Cash and non-cash collateral pledged related to derivative instruments
# under our collateral security arrangements are included in other current assets. 70.Table of Contents Alphabet Inc. The gross amo...
# Embedding (first 5 dimensions): [ 1.20762968  1.65457892 -3.14323187 -1.22197294  0.04653322]...
#
# Document 60:
# Content: Leases
# We have entered into operating lease agreements primarily for data centers, land, and offices throughout the
# world with lease periods expiring between 2024 and 2063. Components of operating lea...
# Embedding (first 5 dimensions): [ 0.02607716  1.70789993 -3.08193469 -0.41860467 -0.55123711]...
#
# Document 61:
# Content: Variable Interest Entities
# Consolidated Variable Interest Entities
# We consolidate VIEs in which we hold a variable interest and are the primary beneficiary. The results of
# operations and financial pos...
# Embedding (first 5 dimensions): [ 1.17018473  0.77784139 -2.17091131 -1.13638258 -0.5281831 ]...
#
# Document 62:
# Content: The notes in the table above are fixed-rate senior unsecured obligations and generally rank equally with each
# other. We may redeem the notes at any time in whole or in part at specified redemption pri...
# Embedding (first 5 dimensions): [ 0.65743726  1.60803652 -3.35078955 -1.32438433  0.83113921]...
#
# Document 63:
# Content: Note 7. Supplemental Financial Statement Information
# Accounts Receivable
# The allowance for credit losses on accounts receivable was $754 million and $771 million as of December 31,
# 2022 and 2023, resp...
# Embedding (first 5 dimensions): [ 0.87193131  1.22488379 -3.26130128 -0.89088142  0.67455304]...
#
# Document 64:
# Content: See Note 10 for further details....
# Embedding (first 5 dimensions): [ 1.00219584  1.10295916 -3.21316719 -0.78655398  0.95359182]...
#
# Document 65:
# Content: 74.Table of Contents Alphabet Inc....
# Embedding (first 5 dimensions): [ 0.36155427  0.92683947 -3.21880364 -1.90419805 -0.37480673]...
#
# Document 66:
# Content: Accumulated Other Comprehensive Income (Loss)
# Components of AOCI, net of income tax, were as follows (in millions):
# Unrealized Gains Unrealized
# Foreign Currency (Losses) on Gains (Losses)
# Translation ...
# Embedding (first 5 dimensions): [-0.25891197  1.28554893 -1.94034052 -0.55984098  0.33088467]...
#
# Document 67:
# Content: Note 8....
# Embedding (first 5 dimensions): [ 0.9524166   0.05214538 -3.07576537 -0.92380983  0.88899094]...
#
# Document 68:
# Content: Workforce Reduction and Other Initiatives
# We have a company-wide effort underway to re-engineer our cost base. As part of this program, in January 2023,
# we announced a reduction of our workforce. As a...
# Embedding (first 5 dimensions): [ 0.32906353  1.75265729 -2.70304871 -0.75596023  0.38252372]...
#
# Document 69:
# Content: 76.Table of Contents Alphabet Inc....
# Embedding (first 5 dimensions): [ 0.17884831  1.11117315 -3.26324201 -1.7163868  -0.49137124]...
#
# Document 70:
# Content: Note 9. Goodwill
# Changes in the carrying amount of goodwill for the years ended December 31, 2022 and 2023 were as follows
# (in millions):
# Google
# Services Google Cloud Other Bets Total
# Balance as of De...
# Embedding (first 5 dimensions): [ 1.64855325  0.8364867  -2.43959379 -0.36186424  0.18828154]...
#
# Document 71:
# Content: 77.Table of Contents Alphabet Inc. Antitrust Investigations
# On November 30, 2010, the EC's Directorate General for Competition opened an investigation into various
# antitrust-related complaints against...
# Embedding (first 5 dimensions): [ 0.70164108  1.85669899 -2.95508528 -0.34859625  1.07133269]...
#
# Document 72:
# Content: We continue to
# cooperate with federal and state regulators in the U.S., the EC, and other regulators around the world. 78.Table of Contents Alphabet Inc. Privacy Matters
# We are subject to a number of ...
# Embedding (first 5 dimensions): [ 0.99766266  2.33741283 -2.40651679  0.25384283  1.10252845]...
#
# Document 73:
# Content: We
# plan to appeal. We also periodically have data incidents that we report to relevant regulators as required by law. These claims, consent orders, lawsuits, regulatory and government investigations, ...
# Embedding (first 5 dimensions): [ 0.66964853  1.30922151 -2.7616601  -0.43111667  1.02309656]...
#
# Document 74:
# Content: Note 11. Stockholders' Equity
# Class A and Class B Common Stock and Class C Capital Stock
# Our Board of Directors has authorized three classes of stock, Class A and Class B common stock, and Class C
# cap...
# Embedding (first 5 dimensions): [ 0.6894815   0.52891874 -2.36540818 -0.16940367  0.79871231]...
#
# Document 75:
# Content: 80.Table of Contents Alphabet Inc. The following table sets forth the computation of basic and diluted net income per share of Class A, Class B, and
# Class C stock (in millions, except per share amount...
# Embedding (first 5 dimensions): [ 0.84812331  0.38515979 -1.61008143 -0.62529719  0.29928797]...
#
# Document 76:
# Content: Compensation Plans
# Stock Plans
# Our stock plans include the Alphabet Amended and Restated 2021 Stock Plan ("Alphabet 2021 Stock Plan") and
# Other Bets stock-based plans....
# Embedding (first 5 dimensions): [-0.03730207  1.57072663 -3.61577582 -0.68005466  0.67101759]...
#
# Document 77:
# Content: Under our stock plans, RSUs and other types of awards may be granted. Under the
# Alphabet 2021 Stock Plan, an RSU award is an agreement to issue shares of our Class C stock at the time the award
# vests....
# Embedding (first 5 dimensions): [ 1.16730475  1.72150326 -3.09924865 -0.30119097  0.30063361]...
#
# Document 78:
# Content: Note 14. Income Taxes
# Income from continuing operations before income taxes consisted of the following (in millions):
# Year Ended December 31,
# 2021 2022 2023
# Domestic operations $ 77,016 $ 61,307 $ 73,...
# Embedding (first 5 dimensions): [ 1.07278252  0.73937035 -2.41105413 -0.38991559  0.41917792]...
#
# Document 79:
# Content: and non-U.S....
# Embedding (first 5 dimensions): [ 0.74952614  0.87261939 -3.53090858  0.50644612  0.20532724]...
#
# Document 80:
# Content: matters....
# Embedding (first 5 dimensions): [ 0.23911719  0.25731966 -3.7279067  -0.71551234  1.33672106]...
#
# Document 81:
# Content: 85.Table of Contents Alphabet Inc....
# Embedding (first 5 dimensions): [ 0.00385299  1.4766351  -3.04180813 -2.47552133  0.17137729]...
#
# Document 82:
# Content: Note 15. Information about Segments and Geographic Areas
# We report our segment results as Google Services, Google Cloud, and Other Bets:
# • Google Services includes products and services such as ads, A...
# Embedding (first 5 dimensions): [ 0.16270585  2.16722465 -3.09501886 -0.91946656  0.34340414]...
#
# Document 83:
# Content: CHANGES IN AND DISAGREEMENTS WITH ACCOUNTANTS ON ACCOUNTING AND FINANCIAL
# DISCLOSURE
# None. ITEM 9A. CONTROLS AND PROCEDURES
# Evaluation of Disclosure Controls and Procedures
# Our management, with the pa...
# Embedding (first 5 dimensions): [-0.34717336  1.76017964 -2.53244138 -1.48561311 -0.61446267]...
#
# Document 84:
# Content: ITEM 9B. OTHER INFORMATION
# 10b5-1 Trading Plans
# During the fiscal quarter ended December 31, 2023, the following Section 16 officer and directors adopted,
# modified or terminated a “Rule 10b5-1 trading...
# Embedding (first 5 dimensions): [ 0.88042963 -0.11816365 -2.01640725 -1.42644215  0.54604155]...
#
# Document 85:
# Content: ITEM 9C. DISCLOSURE REGARDING FOREIGN JURISDICTIONS THAT PREVENT INSPECTIONS
# Not applicable. 89.Table of Contents Alphabet Inc....
# Embedding (first 5 dimensions): [ 0.85693491  1.26880145 -2.8756187  -1.36051905  0.74375284]...
#
# Document 86:
# Content: PART III
# ITEM 10. DIRECTORS, EXECUTIVE OFFICERS, AND CORPORATE GOVERNANCE
# The information required by this item will be included under the caption “Directors, Executive Officers, and
# Corporate Governa...
# Embedding (first 5 dimensions): [ 0.06414822  1.30930877 -2.53949428 -0.77812839  0.12993319]...
#
# Document 87:
# Content: PART IV
# ITEM 15. EXHIBITS, FINANCIAL STATEMENT SCHEDULES
# We have filed the following documents as part of this Annual Report on Form 10-K:
# 1. Consolidated Financial Statements
# Reports of Independent R...
# Embedding (first 5 dimensions): [ 0.4244166   0.75749624 -3.11179304 -0.74018073 -0.25970235]...
#
# Document 88:
# Content: All other schedules have been omitted because they are not required, not applicable, or the required information
# is otherwise included....
# Embedding (first 5 dimensions): [ 0.28440684  0.72651601 -3.05358195 -0.60725492 -0.25792903]...
#
# Document 89:
# Content: 3. Exhibits
# Incorporated by reference herein
# Exhibit
# Number Description Form Date
# 2.01 Agreement and Plan of Merger, dated Current Report on Form 8-K October 2, 2015
# October 2, 2015, by and among Goog...
# Embedding (first 5 dimensions): [ 0.42363372  1.50863755 -1.75706804 -0.81081051  0.16740245]...
#
# Document 90:
# Content: ‡ Furnished herewith....
# Embedding (first 5 dimensions): [ 0.61118942  0.20904106 -3.44574428 -1.39689302 -0.23543914]...
#
# Document 91:
# Content: ITEM 16. FORM 10-K SUMMARY
# None....
# Embedding (first 5 dimensions): [ 0.51131225 -0.30681664 -2.66830611 -1.34688127  0.26588333]...
#
# Document 92:
# Content: 94.Table of Contents Alphabet Inc. SIGNATURES
# Pursuant to the requirements of Section 13 or 15(d) of the Securities Exchange Act of 1934, the Registrant has
# duly caused this Annual Report on Form 10-K...
# Embedding (first 5 dimensions): [ 0.70397449  0.64064556 -2.673311   -0.2987569  -1.30587566]...
#
# Document 93:
# Content: UNITED STATES
# SECURITIES AND EXCHANGE COMMISSION
# Washington, D.C. 20549
# FORM 10-K
# (Mark One)
# x ANNUAL REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934
# For the fiscal year ...
# Embedding (first 5 dimensions): [-0.5401817   1.25919819 -3.37641716 -0.59442419  0.85979223]...
#
# Document 94:
# Content: Yes o No x
# Indicate by check mark whether the registrant (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange Act of 1934 (“Exchange Act”)
# during the preced...
# Embedding (first 5 dimensions): [ 0.34353492  1.06449783 -3.09463978  0.01590025  0.76051593]...
#
# Document 95:
# Content: 7262(b)) by the registered public accounting firm that prepared or issued its audit report. x
# If securities are registered pursuant to Section 12(b) of the Act, indicate by check mark whether the fina...
# Embedding (first 5 dimensions): [ 0.27203402  1.25279725 -2.6709547  -0.361983    0.89158803]...
#
# Document 96:
# Content: Item 1....
# Embedding (first 5 dimensions): [-0.44122362  0.2512089  -3.46953297 -1.21745288  0.32664177]...
#
# Document 97:
# Content: Business 4
# Item 1A. Risk Factors 14
# Item 1B. Unresolved Staff Comments 28
# Item 1C. Cybersecurity 29
# Item 2....
# Embedding (first 5 dimensions): [ 0.57494515  0.62239963 -3.06538844 -0.4429709   1.62507999]...
#
# Document 98:
# Content: Properties 30
# Item 3....
# Embedding (first 5 dimensions): [ 0.40330443 -0.17789686 -3.41315079 -1.65329313  0.01886956]...
#
# Document 99:
# Content: Legal Proceedings 30
# Item 4. Mine Safety Disclosures 30
# PART II. Item 5. Market for Registrant's Common Equity, Related Stockholder Matters and Issuer Purchases of Equity Securities 31
# Item 6. [Reserv...
# Embedding (first 5 dimensions): [ 0.86137891  0.36669171 -3.07498884 -0.29168013  1.06857765]...
#
# Document 100:
# Content: Other Information 94
# Item 9C. Disclosure Regarding Foreign Jurisdictions that Prevent Inspections 94
# PART III. Item 10....
# Embedding (first 5 dimensions): [ 0.93254608  0.67586315 -3.22128606 -0.95983571  0.95349038]...
#
# Document 101:
# Content: Directors, Executive Officers and Corporate Governance 95
# Item 11. Executive Compensation 95
# Item 12. Security Ownership of Certain Beneficial Owners and Management and Related Stockholder Matters 95
# ...
# Embedding (first 5 dimensions): [ 0.31154189  0.9211387  -2.74461985 -0.74454159  0.02234728]...
#
# Document 102:
# Content: Exhibits and Financial Statement Schedules 96
# Item 16. Summary 111
# SignaturesTable of Contents
# Forward-Looking Statements
# The discussions in this Annual Report on Form 10-K contain forward-looking sta...
# Embedding (first 5 dimensions): [-0.15175933  0.86740667 -3.4190917  -1.01557767  0.44020432]...
#
# Document 103:
# Content: We do not assume any obligation to update any forward-looking statements.Table of Contents
# PART I
# ITEM 1. BUSINESS
# Overview
# We design, develop, manufacture, sell and lease high-performance fully elect...
# Embedding (first 5 dimensions): [ 0.52192235  1.66565752 -2.53976512  0.08814786  0.61742246]...
#
# Document 104:
# Content: See Note 2, Summary of
# Significant Accounting Policies, to the consolidated financial statements included elsewhere in this Annual Report on Form 10-K for further details. Programs and Incentives
# Infl...
# Embedding (first 5 dimensions): [-2.23592234  0.78889823 -3.33707952  1.12018549  1.25294173]...
#
# Document 105:
# Content: Our interns engage in meaningful work from day one, and we
# often offer them full-time positions post-internship. • Military Fellowship and Transition Programs – The Military Fellowship and Transition ...
# Embedding (first 5 dimensions): [ 0.52706867  1.02735353 -2.73130083  0.15235214  1.71992028]...
#
# Document 106:
# Content: ITEM 1A. RISK FACTORS
# You should carefully consider the risks described below together with the other information set forth in this report, which could materially affect our
# business, financial condit...
# Embedding (first 5 dimensions): [ 0.56826329  1.44282711 -3.01601124  0.69635129  0.96656066]...
#
# Document 107:
# Content: Our business may suffer if our products or features contain defects, fail to perform as expected or take longer than expected to
# become fully functional. If our products contain design or manufacturin...
# Embedding (first 5 dimensions): [ 0.92277515  0.91102481 -2.57319498  0.26358211  0.61840451]...
#
# Document 108:
# Content: In
# addition, the battery packs that we produce make use of lithium-ion cells. On rare occasions, lithium-ion cells can rapidly release the energy they contain
# by venting smoke and flames in a manner t...
# Embedding (first 5 dimensions): [ 0.65703839  1.77940619 -2.87333417  1.02449965  0.07131188]...
#
# Document 109:
# Content: If we are unable to attract, hire and retain key employees and qualified personnel, our ability to compete may be harmed. The loss of the services of any of our key employees or any significant portio...
# Embedding (first 5 dimensions): [-0.21330628  1.37298059 -2.57959723  0.48063695  0.59590673]...
#
# Document 110:
# Content: and abroad. While, we maintain
# information technology measures designed to protect us against intellectual property theft, data breaches, sabotage and other external or internal cyber-
# attacks or misa...
# Embedding (first 5 dimensions): [ 0.32468495  0.77610332 -2.2753067   1.05590439  0.76657122]...
#
# Document 111:
# Content: Risks Related to Government Laws and Regulations
# Demand for our products and services may be impacted by the status of government and economic incentives supporting the
# development and adoption of suc...
# Embedding (first 5 dimensions): [ 0.57030392  2.04004836 -2.12869835  0.3825238   0.31319478]...
#
# Document 112:
# Content: and international privacy and consumer protection laws may harm us. Any failure by us or our vendors or other business partners to comply with our public privacy notice or with federal, state or inter...
# Embedding (first 5 dimensions): [-0.01871704  2.18652034 -2.59012866  0.14802152  1.21979952]...
#
# Document 113:
# Content: Complying with emerging and changing requirements may
# cause us to incur substantial costs and make enhancements to relevant data practices. Noncompliance could result in significant penalties or legal...
# Embedding (first 5 dimensions): [ 0.55952734  1.64331257 -2.58835745 -0.16595335  1.70329809]...
#
# Document 114:
# Content: Moreover, we expect to incur costs in responding to related requests for information
# and subpoenas, and if instituted, in defending against any governmental proceedings. We may face regulatory challen...
# Embedding (first 5 dimensions): [ 0.46918377  1.4910388  -2.51486444  0.04983868  0.97104871]...
#
# Document 115:
# Content: UNRESOLVED STAFF COMMENTS
# None....
# Embedding (first 5 dimensions): [ 0.94850874  0.1885439  -3.24318361 -1.44885182  1.24567688]...
#
# Document 116:
# Content: 28ITEM 1C. CYBERSECURITY
# Cybersecurity Risk Management and Strategy
# We recognize the importance of assessing, identifying, and managing material risks associated with cybersecurity threats, as such te...
# Embedding (first 5 dimensions): [ 1.35945916  0.16496694 -2.72704268  0.24399285  2.27124929]...
#
# Document 117:
# Content: ITEM 2....
# Embedding (first 5 dimensions): [ 0.1063033  -0.01644583 -3.6497097  -0.76903635  0.30663013]...
#
# Document 118:
# Content: PROPERTIES
# We are headquartered in Austin, Texas. Our principal facilities include a large number of properties in North America, Europe and Asia utilized for
# manufacturing and assembly, warehousing, ...
# Embedding (first 5 dimensions): [ 0.10502475  1.6556077  -3.68045449  0.02807974 -0.34104866]...
#
# Document 119:
# Content: ITEM 3. LEGAL PROCEEDINGS
# For a description of our material pending legal proceedings, please see Note 15, Commitments and Contingencies, to the consolidated financial
# statements included elsewhere in...
# Embedding (first 5 dimensions): [ 1.06811154  1.58381784 -2.94751072 -0.22425     0.61253536]...
#
# Document 120:
# Content: Code § 25100 et seq. and Cal....
# Embedding (first 5 dimensions): [ 0.52495748  0.35629159 -2.89025426 -0.78486985  0.95152217]...
#
# Document 121:
# Content: Civil Code § 1798.80. Tesla has implemented various remedial measures, including conducting training and audits, and
# enhancements to its site waste management programs, and settlement discussions are ...
# Embedding (first 5 dimensions): [ 0.31838697  0.94634384 -2.9185915  -0.9251408   1.64250255]...
#
# Document 122:
# Content: ITEM 4. MINE SAFETY DISCLOSURES
# Not applicable....
# Embedding (first 5 dimensions): [ 1.01760125 -0.07545757 -3.17721486 -0.26202673  1.51542258]...
#
# Document 123:
# Content: 30PART II
# ITEM 5. MARKET FOR REGISTRANT’S COMMON EQUITY, RELATED STOCKHOLDER MATTERS AND ISSUER PURCHASES OF EQUITY
# SECURITIES
# Market Information
# Our common stock has traded on The NASDAQ Global Selec...
# Embedding (first 5 dimensions): [ 1.01452518  0.35194138 -2.38978076 -0.39285237  0.24025449]...
#
# Document 124:
# Content: [RESERVED]
# 32ITEM 7. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS
# The following discussion and analysis should be read in conjunction with the consolidated fin...
# Embedding (first 5 dimensions): [-0.0619862   1.26060843 -2.68979597 -0.90543175  0.09999627]...
#
# Document 125:
# Content: Sustained
# growth has allowed our business to generally fund itself, and we will continue investing in a number of capital-intensive projects and research and
# development in upcoming periods. 33Managem...
# Embedding (first 5 dimensions): [ 1.2959404   0.55545682 -2.8367579  -0.3619194  -0.16173416]...
#
# Document 126:
# Content: Actual results could differ materially from these estimates under different assumptions or conditions. Revenue Recognition
# Automotive Sales
# Automotive sales revenue includes revenues related to cash a...
# Embedding (first 5 dimensions): [ 1.10917664  0.79457527 -2.67735291  0.14063895  1.02251577]...
#
# Document 127:
# Content: and in many foreign jurisdictions. Significant judgment is required in determining our provision for
# income taxes, our deferred tax assets and liabilities and any valuation allowance recorded against ...
# Embedding (first 5 dimensions): [ 0.36138177 -0.52061778 -2.50967097 -0.90427226  0.05623585]...
#
# Document 128:
# Content: 2022 Change 2022 vs. 2021 Change
# (Dollars in millions) 2023 2022 2021 $ % $ %
# Automotive sales $ 78,509 $ 67,210 $ 44,125 $ 11,299 17 % $ 23,085 52 %
# Automotive regulatory credits 1,790 1,776 1,465 14...
# Embedding (first 5 dimensions): [-0.439897    0.97213238 -3.233531   -0.55120611  0.15042023]...
#
# Document 129:
# Content: Automotive regulatory credits includes sales of regulatory credits to other automotive manufacturers. Our revenue from automotive regulatory
# credits is directly related to our new vehicle production, ...
# Embedding (first 5 dimensions): [ 0.2880502   2.00874901 -3.17843723 -0.21155936 -0.65052378]...
#
# Document 130:
# Content: 2022 Change 2022 vs. 2021 Change
# (Dollars in millions) 2023 2022 2021 $ % $ %
# Cost of revenues
# Automotive sales $ 65,121 $ 49,599 $ 32,415 $ 15,522 31 % $ 17,184 53 %
# Automotive leasing 1,268 1,509 97...
# Embedding (first 5 dimensions): [ 1.17359233  0.64914691 -2.7250843  -0.97596407  0.07269683]...
#
# Document 131:
# Content: See Note 14, Income Taxes, to the consolidated financial statements included elsewhere in this Annual Report on Form 10-K for further details. Liquidity and Capital Resources
# We expect to continue to ...
# Embedding (first 5 dimensions): [ 0.47595006  1.37660956 -2.84290648  0.48242125 -0.35437003]...
#
# Document 132:
# Content: government securities and other investments,
# to do more vertical integration, expand our product roadmap and provide financing options to our customers. 43Summary of Cash Flows
# Year Ended December 31,...
# Embedding (first 5 dimensions): [ 1.23182893  0.39304346 -2.35323834 -0.7563172  -0.04247849]...
#
# Document 133:
# Content: 44ITEM 7A. QUANTITATIVE AND QUALITATIVE DISCLOSURES ABOUT MARKET RISK
# Foreign Currency Risk
# We transact business globally in multiple currencies and hence have foreign currency risks related to our re...
# Embedding (first 5 dimensions): [ 0.87474859  0.37079525 -3.08908868 -0.93021464 -0.09574144]...
#
# Document 134:
# Content: 48Tesla, Inc....
# Embedding (first 5 dimensions): [-0.10632123  1.50112545 -3.83817244 -0.6112293  -0.42151913]...
#
# Document 135:
# Content: Consolidated Balance Sheets
# (in millions, except per share data)
# December 31, December 31,
# 2023 2022
# Assets
# Current assets
# Cash and cash equivalents $ 16,398 $ 16,253
# Short-term investments 12,696 5,9...
# Embedding (first 5 dimensions): [ 0.62395608  1.10855544 -3.02069402 -0.92907369  0.05826886]...
#
# Document 136:
# Content: 49Tesla, Inc....
# Embedding (first 5 dimensions): [-0.0973463   1.55122674 -3.88255477 -0.68088567 -0.50107324]...
#
# Document 137:
# Content: Consolidated Statements of Operations
# (in millions, except per share data)
# Year Ended December 31,
# 2023 2022 2021
# Revenues
# Automotive sales $ 78,509 $ 67,210 $ 44,125
# Automotive regulatory credits 1,7...
# Embedding (first 5 dimensions): [ 2.00929022 -0.24806309 -2.63013577 -0.97137403 -0.12709767]...
#
# Document 138:
# Content: 50Tesla, Inc....
# Embedding (first 5 dimensions): [-0.54805249  1.7019701  -3.87719917 -0.76150382 -0.78790975]...
#
# Document 139:
# Content: Consolidated Statements of Comprehensive Income
# (in millions)
# Year Ended December 31,
# 2023 2022 2021
# Net income $ 14,974 $ 12,587 $ 5,644
# Other comprehensive income (loss):
# Foreign currency translatio...
# Embedding (first 5 dimensions): [ 0.45146602  0.6086092  -2.91376829 -0.47363707 -0.26298726]...
#
# Document 140:
# Content: 51Tesla, Inc. Consolidated Statements of Redeemable Noncontrolling Interests and Equity
# (in millions)
# Common Stock Accumulated (Accumulated
# Redeemable Additional Other Deficit) Total Noncontrolling
# No...
# Embedding (first 5 dimensions): [ 0.78251106  0.0840494  -2.41201711 -0.71640342  0.40293047]...
#
# Document 141:
# Content: 52Tesla, Inc. Consolidated Statements of Cash Flows
# (in millions)
# Year Ended December 31,
# 2023 2022 2021
# Cash Flows from Operating Activities
# Net income $ 14,974 $ 12,587 $ 5,644
# Adjustments to reconc...
# Embedding (first 5 dimensions): [ 1.28391528  0.83688396 -2.24341345 -0.24642669  0.27528635]...
#
# Document 142:
# Content: Notes to Consolidated Financial Statements
# Note 1 – Overview
# Tesla, Inc. (“Tesla”, the “Company”, “we”, “us” or “our”) was incorporated in the State of Delaware on July 1, 2003. We design, develop,
# ma...
# Embedding (first 5 dimensions): [ 0.09259015  1.25784266 -3.66825581 -0.33055055  0.74183369]...
#
# Document 143:
# Content: Our Chief Executive Officer, as the chief operating decision maker (“CODM”), organizes our company, manages resource allocations and
# measures performance among two operating and reportable segments: (...
# Embedding (first 5 dimensions): [ 0.32945377  1.30418825 -3.08534431 -0.5111444   1.01897991]...
#
# Document 144:
# Content: All
# intercompany transactions and balances have been eliminated upon consolidation. Use of Estimates
# The preparation of financial statements in conformity with GAAP requires management to make estimat...
# Embedding (first 5 dimensions): [ 1.19878817  1.02713668 -3.10628772 -0.91435039  0.53786647]...
#
# Document 145:
# Content: Actual results could differ materially from these estimates under different assumptions or conditions....
# Embedding (first 5 dimensions): [ 1.43572509  0.80621099 -3.66655898 -0.4044981   0.91838008]...
#
# Document 146:
# Content: Reclassifications
# Certain prior period balances have been reclassified to conform to the current period presentation in the consolidated financial statements and the
# accompanying notes. 54Revenue Reco...
# Embedding (first 5 dimensions): [ 0.15597627  1.07965553 -3.67815113 -0.52414823  0.73745388]...
#
# Document 147:
# Content: Payments are typically received at the point control transfers or in accordance with payment terms
# customary to the business, except sales we finance for which payments are collected over the contract...
# Embedding (first 5 dimensions): [ 0.89729351  1.35454047 -2.73026538 -0.41078496 -0.0618    ]...
#
# Document 148:
# Content: and in many foreign jurisdictions. Income taxes are computed using the asset and liability method, under
# which deferred tax assets and liabilities are determined based on the difference between the fi...
# Embedding (first 5 dimensions): [ 1.73583376  0.28773427 -2.63458872 -0.55005991  0.2930381 ]...
#
# Document 149:
# Content: Costs that are directly attributable to the
# acquisition are expensed as incurred. Identifiable assets (including intangible assets), liabilities assumed (including contingent liabilities) and
# noncontr...
# Embedding (first 5 dimensions): [ 1.32556498  0.16393186 -2.06510234 -0.14557135  0.18554933]...
#
# Document 150:
# Content: Customer deposits are included in Accrued liabilities and
# other on the consolidated balance sheets until refunded, forfeited or applied towards the customer’s purchase balance. Government Assistance P...
# Embedding (first 5 dimensions): [ 0.92693943  1.68646216 -2.93278074 -0.17873684 -0.09139632]...
#
# Document 151:
# Content: The incentive therefore reduces the depreciation expense over the useful lives of
# the related equipment. Nevada Tax Incentives
# In connection with the construction of Gigafactory Nevada, we entered int...
# Embedding (first 5 dimensions): [-0.08300865  2.03131795 -3.41927266 -0.63434684  0.51113456]...
#
# Document 152:
# Content: As of December 31, 2023, the grant funding related to property taxes paid were immaterial. Defined Contribution Plan
# We have a 401(k) savings plan in the U.S. that is intended to qualify as a deferred...
# Embedding (first 5 dimensions): [-0.22897679  0.53932154 -2.60080957 -0.46401328 -0.13696966]...
#
# Document 153:
# Content: During the years ended December 31, 2023, 2022 and 2021 we recorded write-downs of $233 million, $144 million and $106 million,
# respectively, in Cost of revenues in the consolidated statements of oper...
# Embedding (first 5 dimensions): [ 0.35099459  1.42629051 -3.09247971 -0.29228163 -0.0615322 ]...
#
# Document 154:
# Content: Depreciation expense during the years ended December 31, 2023, 2022 and 2021 was $3.33 billion, $2.42 billion and $1.91 billion, respectively. Panasonic has partnered with us on Gigafactory Nevada wit...
# Embedding (first 5 dimensions): [ 0.37751889  1.11152768 -3.10150337 -0.49301368  0.50850338]...
#
# Document 155:
# Content: (2) Taxes payable includes value added tax, income tax, sales tax, property tax and use tax payables. Note 10 – Other Long-Term Liabilities
# Our other long-term liabilities consisted of the following (...
# Embedding (first 5 dimensions): [ 0.96055633  0.74917585 -2.65974236 -0.7208122   0.34617665]...
#
# Document 156:
# Content: (2) There were no restrictions on draw-down or use for general corporate purposes with respect to any available committed funds under our credit
# facilities, except certain specified conditions prior t...
# Embedding (first 5 dimensions): [ 0.8775593   0.2437502  -2.57529926 -0.54873502 -0.45032161]...
#
# Document 157:
# Content: We have lease agreements with lease and non-lease components, and have elected to utilize the practical expedient to account for lease and non-
# lease components together as a single combined lease com...
# Embedding (first 5 dimensions): [ 0.03672142  0.62864566 -2.85250449 -0.2414719  -0.13061167]...
#
# Document 158:
# Content: The balances for the operating and finance leases where we are the lessee are presented as follows (in millions) within our consolidated balance
# sheets:
# December 31, 2023 December 31, 2022
# Operating l...
# Embedding (first 5 dimensions): [ 0.81946564  1.01531053 -3.02807283 -0.02844189 -0.23189346]...
#
# Document 159:
# Content: These operating leases will commence between fiscal year 2024 and 2025 with lease terms of 2 years to 20 years. Operating Lease and Sales-type Lease Receivables
# We are the lessor of certain vehicle an...
# Embedding (first 5 dimensions): [ 0.34802547 -0.38601038 -2.72722316 -0.5802747   0.43421617]...
#
# Document 160:
# Content: Treasury yield for zero-coupon U.S. Treasury notes with maturities approximating each
# grant’s expected life. We use our historical data in estimating the expected term of our employee grants. The expe...
# Embedding (first 5 dimensions): [ 1.23170829  0.83526134 -2.52595401 -0.37346172  0.01741672]...
#
# Document 161:
# Content: The components of the (benefit from) provision for income taxes for the years ended December 31, 2023, 2022 and
# 2021 consisted of the following (in millions):
# Year Ended December 31,
# 2023 2022 2021
# Cu...
# Embedding (first 5 dimensions): [-0.11230678  1.40067267 -3.0739398  -0.77256852 -0.00893494]...
#
# Document 162:
# Content: tax credits (593) (276) (328)
# GILTI inclusion 670 1,279 1,008
# Unrecognized tax benefits 183 252 28
# Change in valuation allowance (5,962) (1,532) 6,165
# Other 161 131 78
# (Benefit from) provision for inc...
# Embedding (first 5 dimensions): [ 1.20585966  0.95220089 -2.49674273 -0.43833825  0.51512748]...
#
# Document 163:
# Content: and various state and foreign jurisdictions. We are currently under examination by the Internal Revenue
# Service (“IRS”) for the years 2015 to 2018. Additional tax years within the periods 2004 to 2014...
# Embedding (first 5 dimensions): [ 0.16636936  1.58915448 -3.24848723  0.6033085  -0.61109704]...
#
# Document 164:
# Content: As of December 31,
# 2023, we have met and expect to meet the tax revenue requirements based on our current level of spend and sales. Legal Proceedings
# Litigation Relating to 2018 CEO Performance Award
# ...
# Embedding (first 5 dimensions): [ 0.10781018  1.53615344 -3.60726333 -0.05840253  0.64347136]...
#
# Document 165:
# Content: Defendants filed their answer on September 17, 2020. On July 14, 2023, the parties filed a Stipulation and Agreement of Compromise and Settlement, which does not involve an admission of any
# wrongdoing...
# Embedding (first 5 dimensions): [ 0.89594483  0.75486004 -3.32475209  0.78661525  0.93165839]...
#
# Document 166:
# Content: District Court for the Northern District of California....
# Embedding (first 5 dimensions): [ 1.00839734  1.47307873 -3.31541562 -0.46948761  0.3344546 ]...
#
# Document 167:
# Content: Several
# ...
# Components of debt, including the associated effective interest rates and maturities were as follows (in millions, except for percentages):
# As...
# Embedding (first 5 dimensions): [ 0.78048569  1.19762671 -2.86852479 -1.5012331   0.41554013]...
#
# Document 322:
# Content: The $2.6 billion is comprised of (i) a $1.1 billion tranche with a maturity date of February 25, 2027, replacing the
# 2016 Senior Secured Term Loan as a Refinancing Term Loan (the “2027 Refinanced Term...
# Embedding (first 5 dimensions): [ 0.79230541  0.95656174 -2.90389252 -0.90579385  0.22324707]...
#
# Document 323:
# Content: The interest rate for the 2027 Refinanced
# Term Loan and the 2025 Refinanced Term Loan is the London Interbank Offered Rate (“LIBOR”) plus 3.50% per annum, subject to a floor of 0.00%. The
# refinancing ...
# Embedding (first 5 dimensions): [ 0.87403047  0.22979167 -2.14309311 -0.73173088 -0.33491758]...
#
# Document 324:
# Content: The Revolving Credit
# Facility may be guaranteed by certain of our material domestic restricted subsidiaries based on certain conditions. The credit agreement contains customary
# covenants restricting o...
# Embedding (first 5 dimensions): [ 0.7511043   1.33832657 -3.1037674  -1.26234615  0.76577455]...
#
# Document 325:
# Content: As of December 31, 2021 and 2022, we had letters of credit outstanding
# of $749 million and $839 million, respectively, of which the letters of credit that reduced the available credit under the Revolv...
# Embedding (first 5 dimensions): [ 0.79444629  0.91608477 -3.58246636 -0.17731646  0.88187027]...
#
# Document 326:
# Content: Upon the conversion, we released the accumulative pre-tax unrealized gains recorded through other comprehensive income and
# recognized them as unrealized gains in other income (expense), net in our con...
# Embedding (first 5 dimensions): [ 1.79360795 -0.31983784 -3.65989065 -1.59217143  0.63594341]...
#
# Document 327:
# Content: Refer to Note 4 – Equity Method Investments for further information. Note 10 – Stockholders' Equity
# Common Stock
# As of December 31, 2022, we have the authority to issue 5.0 billion shares of common st...
# Embedding (first 5 dimensions): [ 1.02726305  1.06326461 -2.56107283  0.2450802   0.46491244]...
#
# Document 328:
# Content: Vesting of this stock may be dependent
# on a combination of service and performance conditions that become satisfied upon the occurrence of a qualifying event. We have the right to repurchase shares fo...
# Embedding (first 5 dimensions): [ 0.82158828  1.3084681  -2.67500949  0.47242513  1.12428212]...
#
# Document 329:
# Content: and foreign components of income (loss) before provision for (benefit from) income taxes for the years ended December 31, 2020, 2021 and 2022 are
# as follows (in millions):
# Year Ended December 31,
# 2020...
# Embedding (first 5 dimensions): [ 0.08817838  0.66239667 -3.04748893  0.20493159  0.92686301]...
#
# Document 330:
# Content: The 2021 rate impact for “Deferred tax on investments” was primarily driven by the deferred China and U.S. tax impact related to our investment in Didi
# and the deferred U.S. tax impact related to our ...
# Embedding (first 5 dimensions): [ 1.11245131  0.82979107 -2.84084773 -0.98023134 -0.07533544]...
#
# Document 331:
# Content: Based on the analysis, we do not anticipate a current limitation on the tax attributes. The following table reflects changes in gross unrecognized tax benefits (in millions):
# Year Ended December 31,
# 2...
# Embedding (first 5 dimensions): [ 0.32742691  1.37292433 -2.77297354 -0.85966533  0.27696568]...
#
# Document 332:
# Content: and various state and foreign jurisdictions. We are also under various state and other foreign income tax examinations. We believe that adequate amounts have been reserved in these jurisdictions. To t...
# Embedding (first 5 dimensions): [ 0.51903349  0.69167358 -2.9434185  -1.04877877  0.46429256]...
#
# Document 333:
# Content: We take into account the effect on consolidated net loss per share of dilutive securities of entities in which we hold equity interests that are accounted for using
# the equity method....
# Embedding (first 5 dimensions): [ 1.34795475  0.77462059 -2.9205904  -1.18656671  1.0332855 ]...
#
# Document 334:
# Content: The following table sets forth the computation of basic and diluted net loss per share attributable to common stockholders (in millions, except share amounts
# which are reflected in thousands, and per ...
# Embedding (first 5 dimensions): [ 0.80586404  1.22850823 -2.85893917 -1.08269095  0.46954206]...
#
# Document 335:
# Content: Effective January 1, 2021, we early adopted ASU 2020-06 using the modified retrospective approach....
# Embedding (first 5 dimensions): [ 0.29362911  0.16784775 -3.0471015  -0.06584138  0.05566198]...
#
# Document 336:
# Content: Upon adoption, we use the if-converted method and
# presume share settlement for our 2025 Convertible Notes and our non-interest bearing unsecured convertible notes related to the acquisition of Careem ...
# Embedding (first 5 dimensions): [ 0.48898295  1.25416696 -2.83714843 -0.85139757  0.69189155]...
#
# Document 337:
# Content: In addition, during
# the second quarter of 2020, we completed the divestiture of our JUMP business (the “JUMP Divestiture”), which comprised substantially all of the operations of
# our Other Bets report...
# Embedding (first 5 dimensions): [ 0.70089692  1.0065043  -2.78656507 -0.58213001 -0.01157407]...
#
# Document 338:
# Content: (3) Includes costs that are not directly attributable to our reportable segments. Corporate G&A also includes certain shared costs such as finance, accounting,
# tax, human resources, information techno...
# Embedding (first 5 dimensions): [ 0.62252909  1.63439608 -3.34014058 -0.97350669  0.39316234]...
#
# Document 339:
# Content: (4) Refer to Note 1 – Description of Business and Summary of Significant Accounting Policies for further information. Geographic Information
# Revenue by geography is based on where the trip or shipment...
# Embedding (first 5 dimensions): [ 0.85499591  0.87622732 -2.39626336  0.76618171  0.94782531]...
#
# Document 340:
# Content: If one or more of these matters
# were resolved against us for amounts in excess of management's expectations, our results of operations, financial condition or cash flows could be materially
# adversely ...
# Embedding (first 5 dimensions): [ 0.20994639  1.15347588 -3.35132122  0.60329342  1.00380909]...
#
# Document 341:
# Content: (“Lyft”). The complaint alleges drivers are misclassified, and seeks an injunction and monetary damages
# related to the alleged competitive advantage caused by the alleged misclassification of drivers....
# Embedding (first 5 dimensions): [ 0.25787801  1.45559669 -2.9600172   0.35344577  1.16772127]...
#
# Document 342:
# Content: Our chances of success on the merits are still uncertain and any reasonably possible loss or range of loss cannot be estimated. In addition, in January 2021, a petition was filed with the California S...
# Embedding (first 5 dimensions): [ 0.20100468  1.51201618 -2.99461889  0.57633245  1.28729796]...
#
# Document 343:
# Content: for social security or labor purposes. We are challenging each of them before the Social Security and Administrative Tribunals. In April 2021, a ruling was made that Uber Switzerland could not be held...
# Embedding (first 5 dimensions): [ 0.60309792  1.34685516 -3.21152806  0.55040067  0.58343685]...
#
# Document 344:
# Content: and
# Rasier Operations B.V. are still pending for years 2014 to 2021. In January 2022, the Social Security Tribunal of Zurich reclassified drivers who have used the App
# in 2014 as dependent workers of ...
# Embedding (first 5 dimensions): [-0.17180149  0.74158776 -3.52033114  0.67916894  0.88026333]...
#
# Document 345:
# Content: Uber B.V., Uber Britannia Ltd....
# Embedding (first 5 dimensions): [-0.72442502  0.87516004 -4.15790319  0.55966306  1.07712412]...
#
# Document 346:
# Content: and Uber London Ltd. On October 28, 2015, a claim by 25 Drivers, including Mr. Y....
# Embedding (first 5 dimensions): [-0.25048226  0.69496119 -4.04833603 -0.20648259  0.86076051]...
#
# Document 347:
# Content: Aslam and Mr....
# Embedding (first 5 dimensions): [ 0.80180907  0.6811949  -2.91504145 -0.4800131   0.45232278]...
#
# Document 348:
# Content: J. Farrar, was brought in the UK Employment Tribunal against us asserting that
# they should be classified as “workers” (a separate category between independent contractors and employees) in the UK rath...
# Embedding (first 5 dimensions): [ 0.00815151  1.07957125 -3.27291012 -0.49341697  1.14906645]...
#
# Document 349:
# Content: We will proceed (or have proceeded) to appeal to the Court of First Instance for each of them. There are ongoing
# audits for which we have not yet received an assessment. Our chances of success on the ...
# Embedding (first 5 dimensions): [ 0.61789066  0.41946164 -3.34926701 -0.45901746  0.72380823]...
#
# Document 350:
# Content: The HMRC
# may disagree with our application of VAT Order 1987, but due to the complexity and uncertainty of these matters and the judicial processes, any reasonably
# possible loss or range of loss canno...
# Embedding (first 5 dimensions): [ 0.38343066  0.69975829 -3.63971019 -1.05836129  0.32531589]...
#
# Document 351:
# Content: Developed technology represents the fair value of Careem’s technology. Trade names relate to the “Careem”
# trade name, trademarks, and domain names. The overall weighted average useful life of the iden...
# Embedding (first 5 dimensions): [ 0.55465442  1.09512651 -2.97631669  0.08386497  0.24670775]...
#
# Document 352:
# Content: The income tax effect of the sale was not
# material. The divestiture of Uber Eats India did not represent a strategic shift that would have had a major effect on our operations and financial results, a...
# Embedding (first 5 dimensions): [ 0.87128943  0.41701287 -2.62887692 -0.46473894 -0.49762419]...
#
# Document 353:
# Content: (2) Total restructuring and related charges included $247 million of cash settled charges, primarily for severance and other termination benefits and were
# substantially paid as of December 31, 2020....
# Embedding (first 5 dimensions): [ 1.62476015  1.13097131 -3.10416555 -0.66243243  0.19813734]...
#
# Document 354:
# Content: 139Schedule II - Valuation and Qualifying Accounts
# The table below details the activity of the allowance for doubtful accounts, deferred tax asset valuation allowance, and insurance reserves (in milli...
# Embedding (first 5 dimensions): [ 1.80309916 -0.34389606 -2.76015592 -0.99757564  0.97762311]...
#
# Document 355:
# Content: ITEM 9A. CONTROLS AND PROCEDURES
# Evaluation of Disclosure Controls and Procedures
# We maintain disclosure controls and procedures that are designed to provide reasonable assurance that information requ...
# Embedding (first 5 dimensions): [ 5.82410693e-01  7.63809367e-05 -3.26422572e+00 -1.32666683e+00
#   1.83641464e-01]...
#
# Document 356:
# Content: OTHER INFORMATION
# Not applicable....
# Embedding (first 5 dimensions): [ 1.4290055   0.90030473 -3.00450945 -0.68519568  0.42487049]...
#
# Document 357:
# Content: ITEM 9C. DISCLOSURE REGARDING FOREIGN JURISDICTIONS THAT PREVENT INSPECTIONS
# Not applicable....
# Embedding (first 5 dimensions): [ 1.2098546   1.2056061  -3.11764336 -0.91183376  1.19525647]...
#
# Document 358:
# Content: PART III
# ITEM 10. DIRECTORS, EXECUTIVE OFFICERS AND CORPORATE GOVERNANCE
# The information required by this item is set forth under the headers “Proposal 1- Election of Directors,” “Executive Officers,”...
# Embedding (first 5 dimensions): [-0.1953707   1.15478218 -2.57018661 -0.63566762 -0.07554175]...
#
# Document 359:
# Content: Exhibits
# The documents listed in the Exhibit Index of this Annual Report on Form 10-K are incorporated by reference or are filed with this Annual Report on Form 10-
# K, in each case as indicated therei...
# Embedding (first 5 dimensions): [-1.579458    0.99716616 -2.45808816  0.19415562  1.48781884]...
#
# Document 360:
# Content: 10.28 Addendum to Employment Agreement, by and between the 10-K 001-38902 10.29 March 2, 2020
# Registrant and Nelson Chai, dated September 1, 2019. 10.29 Addendum to Employment Agreement, by and betwee...
# Embedding (first 5 dimensions): [-0.34659776  0.96325415 -2.59497952 -0.10821127  0.26014689]...
#
# Document 361:
# Content: Section 1350, as adopted
# pursuant to Section 906 of the Sarbanes-Oxley Act of 2002. X
# 101.INS XBRL Instance Document - the instance document does not appear
# in the Interactive Data File because its XB...
# Embedding (first 5 dimensions): [ 0.57023817  1.21873331 -2.86121631 -1.42684436  0.4529078 ]...
#
# Document 362:
# Content: +Portions of this exhibit have been omitted in accordance with Item 601(b)(10)(iv) of Regulation S-K. ‡This form of employment agreement will be used for all named executive officer employment agreeme...
# Embedding (first 5 dimensions): [-0.4129945   0.51530468 -2.56079006  0.68180752  0.42376781]...
#
# Document 363:
# Content: Ltd. Singapore
# Unter, LLC New YorkExhibit 23.1
# CONSENT OF INDEPENDENT REGISTERED PUBLIC ACCOUNTING FIRM
# We hereby consent to the incorporation by reference in the Registration Statements on Form S-8 (...
# Embedding (first 5 dimensions): [-0.09983405  1.06546438 -3.29843712 -0.61959571  0.52779222]...
#
# Document 364:
# Content: 333-239985) of Uber Technologies, Inc. of our report dated February 21, 2023 relating to the financial statements,
# financial statement schedule and the effectiveness of internal control over financial...
# Embedding (first 5 dimensions): [ 0.40756148  0.9673844  -2.98003912  0.15410037  0.67222571]...
#
# Document 365:
# Content: Based on my knowledge, the financial statements, and other financial information included in this report, fairly present in all material respects the
# financial condition, results of operations and cas...
# Embedding (first 5 dimensions): [ 0.55079353  0.0087655  -3.38239241 -0.30355513  0.52547616]...
#
# Document 366:
# Content: The registrant’s other certifying officer and I are responsible for establishing and maintaining disclosure controls and procedures (as defined in Exchange
# Act Rules 13a-15(e) and 15d-15(e)) and inter...
# Embedding (first 5 dimensions): [ 0.06829306  0.73568535 -2.71761966 -0.39413396  1.03595066]...
#
# Document 367:
# Content: The registrant’s other certifying officer and I have disclosed, based on our most recent evaluation of internal control over financial reporting, to the
# registrant’s auditors and the audit committee o...
# Embedding (first 5 dimensions): [ 0.61955994  0.75359249 -2.91707087 -0.11438418  1.12062109]...
#
# Document 368:
# Content: Date: February 21, 2023 By: /s/ Dara Khosrowshahi
# Dara Khosrowshahi
# Chief Executive Officer and Director
# (Principal Executive Officer)Exhibit 31.2
# CERTIFICATION OF PRINCIPAL FINANCIAL OFFICER
# PURSUANT...
# Embedding (first 5 dimensions): [ 0.18897998  0.99733883 -2.915241    0.31745428  0.90014631]...
#
# Document 369:
# Content: Based on my knowledge, the financial statements, and other financial information included in this report, fairly present in all material respects the
# financial condition, results of operations and cas...
# Embedding (first 5 dimensions): [ 0.55079353  0.0087655  -3.38239241 -0.30355513  0.52547616]...
#
# Document 370:
# Content: The registrant’s other certifying officer and I are responsible for establishing and maintaining disclosure controls and procedures (as defined in Exchange
# Act Rules 13a-15(e) and 15d-15(e)) and inter...
# Embedding (first 5 dimensions): [ 0.06829306  0.73568535 -2.71761966 -0.39413396  1.03595066]...
#
# Document 371:
# Content: The registrant’s other certifying officer and I have disclosed, based on our most recent evaluation of internal control over financial reporting, to the
# registrant’s auditors and the audit committee o...
# Embedding (first 5 dimensions): [ 0.61955994  0.75359249 -2.91707087 -0.11438418  1.12062109]...
#
# Document 372:
# Content: Date: February 21, 2023 By: /s/ Nelson Chai
# Nelson Chai
# Chief Financial Officer
# (Principal Financial Officer)Exhibit 32.1
# CERTIFICATIONS OF CHIEF EXECUTIVE OFFICER AND CHIEF FINANCIAL OFFICER
# PURSUANT...
# Embedding (first 5 dimensions): [-0.42083597  1.30273962 -3.03539252  0.53201783  0.7769959 ]...
